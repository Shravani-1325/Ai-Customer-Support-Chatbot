# %% [markdown]
# # AI Chatbot for Customer Support 💬🎙️
#
# - *Author : Shravani More*
# ## 0.1 Setup and Data Cleaning File

# %% [markdown]
# # 1. Business Understnding
#
# **Industry** : E-commerece / Samall Business Customer Support
#
# **Problem Statement**: Small Businesses cannot afford 24/7 human support teams, yet customers expect instant responses to repetitive queries like order tracking, review, return policies, and billing.
#
# **Bussiness Impact of the Problem:**
# - Higher amount of responses -> customer wait time and Fustration -> Lost sales
# - Human Agents wasting time on repetitive FAQs
# - No support outside working hours
#
# >**Solutions :**
#
# A lightweight AI chatbot that auto-handles the top 7 query categories, freeing human agents for complex issues only.

# %% [markdown]
# ## 1.1 Objective & Goal
#
# **Objective** : Creating Rule Based + Ml AI Chatbot MVP that classifies customer intent and returns context - appropriate automed responses via a REST API
#
# **Goal :** End-to-end development of a Python-based intelligent chatbot, featuring a custom intent-classification pipeline and REST API deployment for real-time interaction.

# %% [markdown]
# ## 1.2 Importing Libraries

# %%
import nltk
nltk.download("punkt")
nltk.download("stopwords")
nltk.download("wordnet")
nltk.download("punkt_tab")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
import json
import pandas
import numpy
import matplotlib.pyplot as plt
import seaborn as sns

#nlp
import re
import string
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# %% [markdown]
# # 2. Data Understanding
#
# **Data Source:** Manually created `intent.json` knowlwdge base (no external datasets from any resource).
#
# **Data Structure:**
# - Format: json
# - Total Intents: 7
# - Patterns per Intent: 15 (traning eg)
#
# **Intent Categories :**
# `greetings`, `order_status`, `return_policy`, `billing_inquiry`, `store_hours`, `product_pricing`, `escalate_to_human`

# %% [markdown]
# ## 2.1 Creating the intent.json file
# Creating the chatbot's knowledge base, core data on which Ml model will be traning on.

# %%
# Intents refer to the purpose, goal, or action that a user wants to perform.

intents_data ={
  "intents":[
      {
          "tag": "greetings",
          "patterns": [
              "Hello", "Hi", "Goodmorning", "Goodevening", "Hi there",
              "Hey there", "Howdy", "What 's up", "Greetings", "Good afternoon", "Is anyone there",
              "Hello there", "Hi, I need help", "Hey Can You help me"
          ],
          "responses": [
              "Hello How can I Help you today?",
              "Hi there! What can I do for you today?",
              "Hey! I am here to help. What do you need?",
              "Good to see you! How can I assist?"
          ]
      },

      {
          "tag": "order_status",
          "patterns": [
              "Where is my order", "Track my order", "Order Status",
              "What happened to my package", "My order hasn't arrived",
              "When will my order arrive", "I want to track my shipment",
              "Can you check my order", "My package is late",
              "Where is my shipment", "Order tracking", "Check my order",
              "Is my order on the way", "Order not received", "Delivery status"
          ],
          "responses": [
              "Please share you order ID and I'll check the status for you",
              "I can help you track your order! Could you provide your order number?",
              "To check your order status, I'll need your order ID. Can you share that?",
              "Sure! Please give me your order number and I'll look it up right away."
         ]
      },

      {
          "tag" : "return_policy",
          "patterns": [
            "How do I return a product", "Return policy", "Can I return this",
            "I want to return my order", "What is the return process",
            "How to get a refund", "Return an item", "Exchange a product",
            "Is return free", "Return shipping cost", "How many days to return",
            "I received a wrong product", "Item is damaged, want to return",
            "Can I exchange instead of return", "Refund policy" , "Want to return purchase item",
            "Help me in return Procedure of my Item"
          ],
          "responses": [
            "We have a 30-day return policy. Items must be unused and in original packaging.",
            "You can return any product within 30 days of delivery. Visit our returns portal to initiate.",
            "Returns are easy! Go to your order history, select the item, and click 'Return'. We'll send a pickup.",
            "Our return window is 30 days. Damaged or incorrect items get free return shipping.",
            "Easy Return! Just visit our Return Portal, We have 30-days return policy. Ensure that Product is Unused"
          ]
      },

      {
          "tag": "billing_inquiry",
          "patterns" : [
            "I was charged twice", "Wrong amount charged", "Billing issue",
            "Payment problem", "I didn't receive my invoice", "Where is my receipt",
            "Charge on my card", "Unexpected charge", "Extra charge on account",
            "When will I be charged", "Payment not going through", "Card declined",
            "How do I update payment method", "Change billing details", "Invoice request", "I have payment issue."
          ],
        "responses": [
            "I'm sorry about the billing issue. Could you share your email or order ID so I can investigate?",
            "Billing concerns are important. Please provide your account email and I'll look into it right away.",
            "For payment issues, I'll need your order number. Our finance team will review within 24 hours.",
            "I understand this is urgent. Please share your order ID and we'll resolve any billing discrepancy."
      ]
      },

      {
          "tag": "store_hours",
          "patterns": [
            "What are your working hours", "When are you open", "Store timings",
            "Are you open on Sunday", "What time do you close", "Office hours",
            "When can I reach support", "Is support available 24/7",
            "Customer service hours", "When is your helpdesk open",
            "Do you work on holidays", "Opening hours", "Are you open now",
            "What days are you open", "Support availability"
          ],
          "responses" : [
            "Our support is available Monday to Friday, 9 AM to 6 PM IST.",
            "We're open Mon–Fri, 9 AM–6 PM IST. For urgent issues, email us and we respond within 4 hours.",
            "Our team works 9 AM to 6 PM IST on weekdays. Weekends are handled by email only.",
            "Customer support hours: Monday–Friday, 9:00 AM – 6:00 PM IST. We're closed on public holidays."
          ]
      },

      {
          "tag": "product_pricing",
          "patterns": [
            "How much does it cost", "What is the price", "Pricing details",
            "Is there a discount", "Do you have offers", "Coupon code",
            "Price of the product", "Cost of the service", "What are your charges",
            "Is it free", "Free trial available", "Pricing plans", "Subscription cost",
            "How much for the premium plan", "Cheapest plan available"
          ],
          "responses": [
            "Tell me Product id and I ll share the Pricing details"
            "In which pricing you are intrested - Subscription Plans or Product?"
            "Our plans pricing starts at ₹499/month. Visit our pricing page for full details and plan comparisons.",
            "We have three plans: Basic (₹499), Standard (₹999), and Premium (₹1999) per month",
            "You can check our latest pricing at www.example.com/pricing. We also offer a 14-day free trial!",
            "Pricing varies by plan. Would you like me to explain what's included in each tier?"
      ]
    },

    {
      "tag": "escalate_to_human",
      "patterns": [
            "Talk to a human", "Connect me to an agent", "Speak to customer service",
            "I want to talk to a real person", "Transfer me to support",
            "This isn't helping", "You are not useful", "I need human help",
            "Connect me with someone", "Agent please", "Real support needed",
            "Stop the bot, I want a person", "Escalate my issue", "Supervisor",
            "This bot is useless"
      ],
      "responses": [
            "I understand! Let me connect you with a human agent. Please hold for a moment.",
            "I'll transfer you to our support team right away. Average wait time is 2–3 minutes.",
            "Of course! I'm escalating this to a live agent. They'll be with you shortly.",
            "No problem! Connecting you to a customer support specialist now. Thank you for your patience."
      ]
    },
    {
      "tag" : "chitchat",
      "patterns": [
            "ok", "fine", "okay", "alright", "got it", "sure",
            "I see", "makes sense", "understood", "noted",
            "ok thanks", "fine thank you", "alright thanks",
            "ok got it", "sure thing", "that's fine",
            "hmm okay", "ah okay", "oh I see", "right okay",
            "sounds good", "perfect", "great thanks", "nice",
            "cool", "good", "yeah okay", "yep", "yup"

      ],
      "responses" : [
          "Happy to help! Is there anything else i can assis you with?",
          "Got it! Let me know if you have any other questions",
          "Of course! Feel free to ask if you need anything else",
          "Glad I could help! Anything else on your mind?"
      ]
    },
      {
      "tag": "shipping_delay",
      "patterns": [
          "My order is delayed", "Why is my delivery late",
          "My package has not arrived yet", "Delivery is taking too long",
          "Expected delivery was yesterday", "My shipment is stuck",
          "Where is my delayed order", "My order is past the delivery date",
          "It has been 2 weeks and no delivery", "Shipping is very slow",
          "My parcel is delayed", "Why hasn't my order shipped yet",
          "Order is showing delayed in tracking", "Delivery date has passed",
          "My package is stuck in transit", "Shipment not moving",
          "Tracking shows no update for days", "Order delayed no update",
          "Why is shipping taking so long", "Estimated delivery passed",
          "My courier is late", "Package not delivered on time",
          "Still waiting for my order", "Delivery is overdue"
      ],
      "responses": [
          "I'm sorry for the delay! Shipments can sometimes be delayed due to high demand or logistics issues. Please share your order ID and I'll check the status.",
          "Apologies for the inconvenience. Could you share your order number so I can investigate the delay with our shipping team?",
          "I understand how frustrating a delayed delivery can be. Please provide your order ID and we'll prioritise a resolution.",
          "We're sorry your package hasn't arrived yet. Share your order ID and I'll escalate this to our shipping team immediately."
      ]
    }
 ]
}
# Saving the json file
with open("intents.json", "w") as f:
  json.dump(intents_data, f, indent = 2)
print("Json saved successfully !!")
# Out:
# Json saved successfully !!

# %% [markdown]
# ## 2.2 Verifying and Exploring the JSON file

# %%
# Saved and Reading
with open("intents.json", "r") as f:
  loaded = json.load(f)

print(f"intents.json created!!!!!")
print(f"Total intents: {len(loaded["intents"])}")
for intent in loaded["intents"]:
  print(f"-> {intent["tag"]} : {len(intent["patterns"])} patterns, {len(intent["responses"])} responses")
# Out:
# intents.json created!!!!!
# Total intents: 9
# -> greetings : 14 patterns, 4 responses
# -> order_status : 15 patterns, 4 responses
# -> return_policy : 17 patterns, 5 responses
# -> billing_inquiry : 16 patterns, 4 responses
# -> store_hours : 15 patterns, 4 responses
# -> product_pricing : 15 patterns, 4 responses
# -> escalate_to_human : 15 patterns, 4 responses
# -> chitchat : 29 patterns, 4 responses
# -> shipping_delay : 24 patterns, 4 responses

# %% [markdown]
# # 3. Data Cleaning
# Preprocessing transforms messy human text into something a machine can work with mathematically

# %% [markdown]
# ## 3.1  NLP Preprocessing Pipeline
# Architected a reusable `NLPProcessor` class that cleans and transforms
# any raw user query into a format the ML model can understand.
#
# > Text Preprocessing
#
# 1. **Tokenization**- Breaking sentence into individual words.
#
# 2. **Stopword Removal** - Removing useless/common words (I, am, the, is, very)
#
# 3. **Lemmatization** - Converting to root form ("feeling" → "feel)

# %%
# NLP Class
class NLPProcessor:
  def __init__(self):
    self.lemmatizer = WordNetLemmatizer()
    self.stop_words = set(stopwords.words("english"))
    self.stop_words.discard("no")
    self.stop_words.discard("not")

  def clean_text(self, x):
    x =  x.lower()

    # Punctuation
    for i in x:
      if i in string.punctuation:
        x = x.replace(i, "")
    x = "".join([char for char in x if not char.isdigit()])
    x = " ".join(x.split()) # space removing

    return x

  def preprocess_text(self, x):
    x = str(x)

    # Tokenization
    words = word_tokenize(x) # Breaking sentence into individual words.

    # Stopswords + Lemmatization
    cleaned_words = []

    for word in words:
      if word not in self.stop_words: # Removing useless/common words
        lem = self.lemmatizer.lemmatize(word) # Converting to root form
        cleaned_words.append(lem)


    return " ".join(cleaned_words)


# Main Function
  def main(self, text):
    x = self.clean_text(text)
    token = self.preprocess_text(x)

    return token

# %%
# Testing on Single Sentence
t = NLPProcessor()
t.main("CAt is Running in the Garden")
# Out:
# 'cat running garden'

# %% [markdown]
# ## 3.2 Testing on Samples
# Testing the pipeline on one query from each of the 7 intents

# %%
# Creting Object of the class
processor = NLPProcessor()

test_queries = [
   # Intent queries
    ("greeting", "Hey there! How are you doing?"),
    ("order_status", "WHERE IS MY ORDER!!!! I haven't received it yet"),
    ("return_policy",  "How do I return a damaged product??"),
    ("billing_inquiry",  "I was charged TWICE on my credit card!!!"),
    ("store_hours",  "Are you guys open on Sundays?"),
    ("product_pricing",  "What is the price of your premium plan?"),
    ("escalate_to_human", "This bot is useless, I want a real person"),
    ("chitchat", "make sense"),
    ("shipping_delay", "My order is delayed")

]

print(f"{'Intent': <25} {'Raw Input': <55} {'Cleaned Text': <55} {'Final Tokens'}")
print("-"*200)

for intent, query in test_queries:
  tokens = processor.main(query)

  # Showing Cleaned text output too
  cleaned = processor.clean_text(query)
  print(f"{intent:<25} {query:<55} {cleaned:<55} {tokens}")
# Out:
# Intent                    Raw Input                                               Cleaned Text                                            Final Tokens
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# greeting                  Hey there! How are you doing?                           hey there how are you doing                             hey
# order_status              WHERE IS MY ORDER!!!! I haven't received it yet         where is my order i havent received it yet              order havent received yet
# return_policy             How do I return a damaged product??                     how do i return a damaged product                       return damaged product
# billing_inquiry           I was charged TWICE on my credit card!!!                i was charged twice on my credit card                   charged twice credit card
# ...

# %% [markdown]
# ## 3.3 Saving `nlp_processor.py`
# Saving the NLPProcessor class as a standalone Python file for further use

# %%
nlp_code = '''import re
import string
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

class NLPProcessor:
  def __init__(self):
    self.lemmatizer = WordNetLemmatizer()
    self.stop_words = set(stopwords.words("english"))
    self.stop_words.discard("no")
    self.stop_words.discard("not")

  def clean_text(self, x):
    x =  x.lower()

    # Punctuation
    for i in x:
      if i in string.punctuation:
        x = x.replace(i, "")
    x = "".join([char for char in x if not char.isdigit()])
    x = " ".join(x.split())

    return x

  def preprocess_text(self, x):
    x = str(x)

    # Tokenization
    words = word_tokenize(x)

    # Stopswords + Lemmatization
    cleaned_words = []

    for word in words:
      if word not in self.stop_words:
        lem = self.lemmatizer.lemmatize(word)
        cleaned_words.append(lem)

    return " ".join(cleaned_words)



  def main(self, text):
    x = self.clean_text(text)
    token = self.preprocess_text(x)

    return token
'''

# Saving FIle
with open("nlp_processor.py", "w") as f:
  f.write(nlp_code)

print("nlp_processor.py saved to colab")
# Out:
# nlp_processor.py saved to colab
